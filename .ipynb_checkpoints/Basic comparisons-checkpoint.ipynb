# %% [markdown]
# # Basic comparisons
#
# In this notebook look at plotting the positions of different telescopes changes from 2012 to 2019

# %%
from scripts import * 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import networkx as nx

# %%
# load in all the data, clean it, and find the model parameters 
design_mat_04_07, pinv_04_07, y_04_07, beta_04_07 = load_and_clean('2019_04_07')
design_mat_04_08, pinv_04_08, y_04_08, beta_04_08 = load_and_clean('2019_04_08')
design_mat_11_05, pinv_11_05, y_11_05, beta_11_05 = load_and_clean('2019_11_05')
design_mat_11_06, pinv_11_06, y_11_06, beta_11_06 = load_and_clean('2019_11_06')

sigma_04_07 = svd_uncertainty(design_mat_04_07, y_04_07, beta_04_07)[:15].reshape(5,3)
sigma_04_08 = svd_uncertainty(design_mat_04_08, y_04_08, beta_04_08)[:15].reshape(5,3)
sigma_11_05 = svd_uncertainty(design_mat_11_05, y_11_05, beta_11_05)[:15].reshape(5,3)
sigma_11_06 = svd_uncertainty(design_mat_11_06, y_11_06, beta_11_06)[:15].reshape(5,3)

beta_04_07 = beta_04_07[:15].reshape(5,3)
beta_04_08 = beta_04_08[:15].reshape(5,3)
beta_11_05 = beta_11_05[:15].reshape(5,3)
beta_11_06 = beta_11_06[:15].reshape(5,3)

# %%
sigma_04_08
# Out:
# array([[3.03401589e-05, 1.05310003e-04, 1.48686045e-04],
#        [7.73047869e-05, 2.66336254e-04, 2.68878419e-04],
#        [2.98947276e-04, 3.45911964e-05, 1.17433310e-04],
#        [3.51595033e-04, 2.29180445e-04, 3.52989308e-04],
#        [5.02196174e-05, 7.93942773e-05, 6.44199976e-05]])

# %% [markdown]
# # 2019 Apr-Nov

# %%
# for each telescope (wrt E1) it is probably easiest visualise (x, y) and (z) locations

for i in range(5):

    plt.scatter(beta_04_07[i,0], beta_04_07[i,1], label='7 Apr')
    plt.scatter(beta_04_08[i,0], beta_04_08[i,1], label='8 Apr')
    #plt.scatter(beta_11_05[i,0], beta_11_05[i,1], label='05 Nov')
    #plt.scatter(beta_11_06[i,0], beta_11_06[i,1], label='06 Nov')

    plt.errorbar(beta_04_07[i,0], beta_04_07[i,1], xerr=sigma_04_07[i,0], yerr=sigma_04_07[i,1])
    plt.errorbar(beta_04_08[i,0], beta_04_08[i,1], xerr=sigma_04_08[i,0], yerr=sigma_04_08[i,1])
    #plt.errorbar(beta_11_05[i,0], beta_11_05[i,1], xerr=sigma_11_05[i,0], yerr=sigma_11_05[i,1])
    #plt.errorbar(beta_11_06[i,0], beta_11_06[i,1], xerr=sigma_11_06[i,0], yerr=sigma_11_06[i,1])
    plt.legend()
    plt.show()

# %%
# for i in range(5):

#     plt.scatter(beta_04_07[i,2], label='7 Apr')
#     plt.scatter(beta_04_08[i,2], label='8 Apr')
#     plt.scatter(beta_11_05[i,2], label='05 Nov')
#     plt.scatter(beta_11_06[i,2], label='06 Nov')

#     plt.errorbar(beta_04_07[i,2], yerr=sigma_04_07[i,1])
#     plt.errorbar(beta_04_08[i,2], yerr=sigma_04_08[i,1])
#     plt.errorbar(beta_11_05[i,2], yerr=sigma_11_05[i,1])
#     plt.errorbar(beta_11_06[i,2], yerr=sigma_11_06[i,1])
#     plt.legend()
#     plt.show()

# %%
# the POP term can drift to hundred of micron level in a single night 
df = pd.read_csv('data/2019_04_07.csv')

plot_graph(df.loc[:50, :], day_of_year=-1)
# Out:
# /var/folders/yr/nz2d8_8n42g11zxgd7yjxhq40000gn/T/ipykernel_843/315653599.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['telpop_1'] = df.tel_1 + df.pop_1
# /var/folders/yr/nz2d8_8n42g11zxgd7yjxhq40000gn/T/ipykernel_843/315653599.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['telpop_2'] = df.tel_2 + df.pop_2

# %% [markdown]
# # 2012
#
# Since the 2012 data set can be much more sparse, need to check for degeneracies etc.

# %%
# first see what days have nice amounts of data
sns.histplot(df_2012.dayofyear, bins=365)
plt.title('# of telescope measurements on single night 2012')
plt.xlabel('Day of year')
plt.show()

# %%
df = pd.read_csv('data/2012_all_v2.csv')

df['telpop_1'] = df.tel_1 + '-' + df.pop_1
df['telpop_2'] = df.tel_2 + '-' + df.pop_2

graph_df = df.groupby(['telpop_1','telpop_2']).size().reset_index().rename(columns={0:'count'})
G = nx.from_pandas_edgelist(graph_df, source='telpop_1', target='telpop_2')

nx.draw(G, with_labels=True)
plt.show()

# %%
# first it may be worth comparing Apr and Nov in 2012 and 2019 
# also divide into subset of two months 

# also know that the constant term varys on the level on 100s microns each night 
# but we say that pop settings are constant

# %%
df = pd.read_csv('data/2012_all_v2.csv')

df = df[(df.month == 6)] #& ((df.day == 8))]

df['telpop_1'] = df.tel_1 + '-' + df.pop_1
df['telpop_2'] = df.tel_2 + '-' + df.pop_2

graph_df = df.groupby(['telpop_1','telpop_2']).size().reset_index().rename(columns={0:'count'})
G = nx.from_pandas_edgelist(graph_df, source='telpop_1', target='telpop_2')

nx.draw(G, with_labels=True)
plt.show()

# %%
df.groupby(['telpop_1','telpop_2']).size().reset_index().rename(columns={0:'count'})
# Out:
#     telpop_1 telpop_2  count
# 0    E1-P1B1  E2-P3B2    214
# 1    E1-P1B1  W1-P4B3    124
# 2    E1-P1B3  W1-P1B1     28
# 3    E1-P1B3  W2-P5B2     28
# 4    E1-P1B4  E2-P1B5      2
# ..       ...      ...    ...
# 112  W1-P1B1  W2-P5B6     11
# 113  W1-P2B1  W2-P5B6     10
# 114  W1-P2B2  W2-P5B3     82
# 115  W1-P3B1  W2-P5B6      5
# 116  W1-P4B1  W2-P5B6      1
#
# [117 rows x 3 columns]

# %%
# now solve for this 
design_mat_2012, pinv_2012, y_2012, beta_2012 = create_design_mat(df)

sigma_2012 = svd_uncertainty(design_mat_2012, y_2012, beta_2012)[:15].reshape(5,3)
beta_2012 = beta_2012[:15].reshape(5,3)

# %%
# or split the 2012 dataset into two month chunks 
actual_locations_2005 - beta_2012
# Out:
# array([[0.024546  , 0.01803465, 0.05913819],
#        [0.0375594 , 0.02633058, 0.07343288],
#        [0.03905283, 0.02828436, 0.04057512],
#        [0.03819534, 0.02676083, 0.04753908],
#        [0.0320936 , 0.02666467, 0.03366666]])

# %%
def plot_xy(design_mat, y, beta, i):
    
    plt.scatter(beta[i,0], beta[i,1], label=f'{}{}')

# %%
for i in range(4):

    plt.scatter(beta_2012[i,0], beta_2012[i,1], label='2012')
    plt.scatter(beta_04_07[i,0], beta_04_07[i,1], label='7 Apr')
    plt.scatter(beta_04_08[i,0], beta_04_08[i,1], label='8 Apr')
    plt.scatter(beta_11_05[i,0], beta_11_05[i,1], label='05 Nov')
    plt.scatter(beta_11_06[i,0], beta_11_06[i,1], label='06 Nov')
    plt.scatter(actual_locations_2005[i,0], actual_locations_2005[i,1], label='2005')
    

    plt.errorbar(beta_2012[i,0], beta_2012[i,1], xerr=sigma_2012[i,0], yerr=sigma_2012[i,1])
    plt.errorbar(beta_04_07[i,0], beta_04_07[i,1], xerr=sigma_04_07[i,0], yerr=sigma_04_07[i,1])
    plt.errorbar(beta_04_08[i,0], beta_04_08[i,1], xerr=sigma_04_08[i,0], yerr=sigma_04_08[i,1])
    plt.errorbar(beta_11_05[i,0], beta_11_05[i,1], xerr=sigma_11_05[i,0], yerr=sigma_11_05[i,1])
    plt.errorbar(beta_11_06[i,0], beta_11_06[i,1], xerr=sigma_11_06[i,0], yerr=sigma_11_06[i,1])
    plt.legend()
    plt.show()

i = 4   
    
plt.scatter(beta_2012[i,0], beta_2012[i,1], label='2012')
plt.scatter(beta_04_07[i,0], beta_04_07[i,1], label='7 Apr')
plt.scatter(beta_04_08[i,0], beta_04_08[i,1], label='8 Apr')
plt.scatter(actual_locations_2005[i,0], actual_locations_2005[i,1], label='2005')

plt.errorbar(beta_2012[i,0], beta_2012[i,1], xerr=sigma_2012[i,0], yerr=sigma_2012[i,1])
plt.errorbar(beta_04_07[i,0], beta_04_07[i,1], xerr=sigma_04_07[i,0], yerr=sigma_04_07[i,1])
plt.errorbar(beta_04_08[i,0], beta_04_08[i,1], xerr=sigma_04_08[i,0], yerr=sigma_04_08[i,1])
plt.legend()
plt.show()

# %%
# Now we must split the dataset into chunks 
# NB that the SVD error becomes huge for large periods due to the changing POPs 
# i.e. the constant term aint constant!
# 7th of May is highly connected for the telescopes

# %%
# need to create an equation that tells me if the data is degenerate
# done by setting unique tel-pop combo as a node in a network
# if it is disconnected then there are degeneracies

# problem is that tel1 are keywords whilst the pop setting is one hot encoded into df
# could use the design matrix instead ? 
# need to find the

# %% [markdown]
# ## Looking at the most measured days in 2012

# %%
# here we find the days or set of days with the errors under than threshold amount
# the number of good days doesn't really increase as the error increases
# this shows that are days that are right or wrong 
find_good_days(df, bin_size=1, error_threshold=0.1)
# Out:
# [119, 132, 160, 165, 230, 231, 259, 274, 275, 305]

# %%
# here we find the days of the years with more than n measurements

vc = df_2012.dayofyear.value_counts()

trunc_days = df_2012[df_2012.dayofyear.isin(vc.index[vc.values > 350])].dayofyear.value_counts().index

# %%
good_days = []

for day in range(1, 367):
    
    # sets of three days where the max error from actual locations less than 0.1m
    df_temp = df[(day - 5 < df.dayofyear) & (df.dayofyear < day + 5)]

    design_mat, pinv, y, beta = create_design_mat(df_temp)
    
    beta = beta[:15].reshape(5,3)
    
    if np.max(abs(actual_locations_2005 - beta)) < 0.1: 
        good_days.append(day)
    
len(good_days)
# Out:
# 153

# %%
df = df_2012

for i in range(5):

    for day in good_days:
        
        df_temp = df[(day - 2 < df.dayofyear) & (df.dayofyear < day + 2)]
        
        design_mat, pinv, y, beta = create_design_mat(df_temp)
        sigma = svd_uncertainty(design_mat, y, beta)[:15].reshape(5,3)
        beta = beta[:15].reshape(5,3)
        
        
        plt.scatter(beta[i,0], beta[i,1], label=f'{df_temp.dayofyear.values[0]}')
        plt.errorbar(beta[i,0], beta[i,1], xerr=sigma[i,0], yerr=sigma[i,1])
    
    plt.legend()
    plt.show()

# %%
df = df_2012

for i in range(5):

    for day in good_days:
        
        df_temp = df[(day - 2 < df.dayofyear) & (df.dayofyear < day + 2)]
        
        design_mat, pinv, y, beta = create_design_mat(df_temp)
        sigma = svd_uncertainty(design_mat, y, beta)[:15].reshape(5,3)
        beta = beta[:15].reshape(5,3)
        
        
        plt.scatter(beta[i,0], beta[i,1], label=f'{df_temp.dayofyear.values[0]}')
        plt.errorbar(beta[i,0], beta[i,1], xerr=sigma[i,0], yerr=sigma[i,1])
    
    plt.legend()
    plt.show()

# %%
df_temp = df[df.dayofyear == 239]

design_mat, pinv, y, beta = create_design_mat(df_temp)

beta = beta[:15].reshape(5,3)

np.min(abs(actual_locations_2005 - beta))
# Out:
# 0.01791487048048168

# %%
# earthquake started at 0430 utc
df_temp = df[df.dayofyear == 239]

design_mat, pinv, y, beta = create_design_mat(df_temp)
    
plt.plot(np.arange(len(y)), y - design_mat @ beta)
plt.show()

# %%
actual_locations_2005 - beta_04_07
# Out:
# array([[0.01865417, 0.01950894, 0.05741423],
#        [0.03370221, 0.02956052, 0.07431379],
#        [0.03664326, 0.02854241, 0.04025323],
#        [0.03448527, 0.03085115, 0.04310373],
#        [0.02673789, 0.03571851, 0.03059554]])

# %%
sigma_04_07
# Out:
# array([[4.75533798e-05, 7.14779973e-05, 1.14334813e-04],
#        [1.32328720e-04, 1.79798857e-04, 1.14112933e-04],
#        [2.67224872e-04, 6.94468238e-04, 8.26562163e-04],
#        [5.27509711e-04, 4.32710527e-04, 9.07743115e-04],
#        [6.93227882e-04, 1.58779245e-03, 2.07428741e-03]])

# %%
def plot_graph(df, day_of_year=-1):
    
    if day_of_year != -1:
        df = df[df.dayofyear == day_of_year]


    df['telpop_1'] = df.tel_1 + df.pop_1
    df['telpop_2'] = df.tel_2 + df.pop_2

    graph_df = df.groupby(['telpop_1','telpop_2']).size().reset_index().rename(columns={0:'count'})
    G = nx.from_pandas_edgelist(graph_df, source='telpop_1', target='telpop_2')

    nx.draw(G, with_labels=True)
    plt.show()
